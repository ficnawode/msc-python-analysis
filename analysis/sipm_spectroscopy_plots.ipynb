# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

plt.rcParams['figure.figsize'] = FIGSIZE
plt.rcParams['figure.dpi'] = 300
# set tight layout for all plots
plt.rcParams['figure.autolayout'] = True

# %%
Cs137_path='data/sipm_spectroscopy/vp2ps_20250325-100124_cs137_1h_20cm.csv'
Co60_path='data/sipm_spectroscopy/vp2ps_20250323-150545_co60_18h.csv'
Na22_path='data/sipm_spectroscopy/vp2ps_20250317-162839_na22_1h.csv'
Cs137_df = pd.read_csv(Cs137_path)
Co60_df = pd.read_csv(Co60_path)
Na22_df = pd.read_csv(Na22_path)

Cs137_df['mV'] = Cs137_df['V'] * 1000
Co60_df['mV'] = Co60_df['V'] * 1000
Na22_df['mV'] = Na22_df['V'] * 1000

# %%
min =10 
max = 50
step = 0.4 #mV
hist_bins = np.arange(min-step/2, max+step/2, step)
fig, ax = plt.subplots(3,1,figsize=(5, 8))
ax[0].hist(Cs137_df['mV'], range=(min,max), bins=hist_bins, color='black', label='Cs137', histtype='step')
ax[1].hist(Na22_df['mV'], range=(min,max),bins=hist_bins, color='black', label='Na22', histtype='step')
ax[2].hist(Co60_df['mV'], range=(min,max),bins=hist_bins, color='black', label='Co60', histtype='step')
# Out:
# (array([   0.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,    2.,
#           35.,  223.,  598., 1102., 1307., 1326., 1189., 1214., 1155.,
#         1156., 1084., 1074., 1048.,  949., 1008.,  913.,  868.,  828.,
#          799.,  808.,  752.,  751.,  765.,  695.,  707.,  694.,  690.,
#          667.,  656.,  663.,  650.,  636.,  677.,  624.,  587.,  579.,
#          541.,  583.,  509.,  508.,  541.,  510.,  550.,  591.,  632.,
#          622.,  682.,  693.,  738.,  680.,  699.,  663.,  676.,  653.,
#          635.,  605.,  602.,  625.,  521.,  539.,  514.,  474.,  408.,
#          411.,  319.,  330.,  247.,  262.,  192.,  179.,  156.,  116.,
#          116.,  101.,   74.,   51.,   54.,   50.,   35.,   44.,   33.,
#           26.,   22.,   26.,   28.,   32.,   23.,   26.,   24.,   27.,
#           13.,   28.]),
#  array([ 9.8, 10.2, 10.6, 11. , 11.4, 11.8, 12.2, 12.6, 13. , 13.4, 13.8,
#         14.2, 14.6, 15. , 15.4, 15.8, 16.2, 16.6, 17. , 17.4, 17.8, 18.2,
#         18.6, 19. , 19.4, 19.8, 20.2, 20.6, 21. , 21.4, 21.8, 22.2, 22.6,
#         23. , 23.4, 23.8, 24.2, 24.6, 25. , 25.4, 25.8, 26.2, 26.6, 27. ,
#         27.4, 27.8, 28.2, 28.6, 29. , 29.4, 29.8, 30.2, 30.6, 31. , 31.4,
#         31.8, 32.2, 32.6, 33. , 33.4, 33.8, 34.2, 34.6, 35. , 35.4, 35.8,
#         36.2, 36.6, 37. , 37.4, 37.8, 38.2, 38.6, 39. , 39.4, 39.8, 40.2,
#         40.6, 41. , 41.4, 41.8, 42.2, 42.6, 43. , 43.4, 43.8, 44.2, 44.6,
#         45. , 45.4, 45.8, 46.2, 46.6, 47. , 47.4, 47.8, 48.2, 48.6, 49. ,
#         49.4, 49.8, 50.2]),
#  [<matplotlib.patches.Polygon at 0x7faf3c907920>])
